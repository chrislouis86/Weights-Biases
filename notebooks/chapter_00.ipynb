# %% [markdown]
# ## Chapter 0: Setup
#
# <a target="_blank" href="https://colab.research.google.com/github/wandb/eval-course/blob/main/notebooks/chapter_00.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <!--- @wandbcode{eval-course-00} -->
#
# Let's install the required packages and check our setup for this course.
#
# ### 🎉 Free Google AI Studio Access
#
# Before you run this colab notebook, you'll need access to Google's Generative AI models. Here's how to get started:
#
# 1. Visit [Google AI Studio](https://makersuite.google.com/app/home) and sign in with your Google account
# 2. Get your API key from the "Get API key" section in Google AI Studio
#
# Alternatively, if you already have a Google AI Studio API key, feel free to proceed. :)

# %%
# !pip install -qq weave google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.5/983.5 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 41.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.9/52.9 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 109.2 MB/s eta 0:00:00

# %% [markdown]
# ## 1. Setup Weave
#
#
# The code cell below will prompt you to put in a W&B API key. You can get your API key by heading over to https://wandb.ai/authorize.

# %%
# import weave
import weave

# initialize weave client
weave_client = weave.init("eval_course_ch0")
# Out:
# weave: Please login to Weights & Biases (https://wandb.ai) to continue...
# wandb: WARNING The anonymous parameter to wandb.login() has no effect and will be removed in future versions.
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=weave
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: ERROR Invalid API key: API key must have 40+ characters, has 36.
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=weave
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: chris-morgan-708 (chrismorgan) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# weave: Logged in as Weights & Biases user: chris-morgan-708.
# weave: View Weave data at https://wandb.ai/chrismorgan/eval_course_ch0/weave

# %% [markdown]
# ## 2. Setup Google AI Studio
#
# The code cell below will prompt you to put in a Google AI Studio API key.

# %%
import getpass

import google.generativeai as genai

genai.configure(api_key=getpass.getpass("Please enter your Google AI Studio API key"))
# Out:
# Please enter your Google AI Studio API key··········

# %% [markdown]
# ## A simple-turn chat with Google AI Studio's gemini-2.5-flash-exp

# %%
import google.generativeai as genai

# Listing models (optional, for reference):
# for m in genai.list_models():
#   if 'generateContent' in m.supported_generation_methods:
#     print(m.name)

# Use a supported model, for example 'gemini-2.5-flash'
model = genai.GenerativeModel("gemini-2.5-flash") # Changed model name to gemini-2.5-flash
response = model.generate_content("Explain how AI works")
print(response.text)
# Out:
# AI, or Artificial Intelligence, is a broad field of computer science that aims to create machines capable of performing tasks that typically require human intelligence. This involves capabilities like learning, problem-solving, pattern recognition, understanding language, making decisions, and even creativity.
#
# While the concept of AI is vast, the dominant approach that has led to most of the breakthroughs we see today is **Machine Learning (ML)**, and more specifically, **Deep Learning (DL)**.
#
# Let's break down how AI generally works, focusing on these key components:
#
# ---
#
# ### The Core Idea: Learning from Data
#
# At its heart, modern AI (especially Machine Learning) doesn't work by being explicitly programmed with every single rule for every possible scenario. Instead, it **learns from data**. Imagine teaching a child: you don't give them a list of rules for every object they might encounter; you show them many examples of cats, dogs, cars, etc., and they gradually learn to identify new ones on their own. AI works similarly.
#
# ---
#
# ### How Machine Learning (ML) Works
#
# Machine Learning is a subset of AI that gives systems the ability to automatically learn and improve from experience without being explicitly programmed.
#
# **1. Data Collection & Preparation:**
# *   **The Fuel:** AI needs data – lots of it! This could be images, text, numbers, audio, video, etc.
# *   **Cleaning & Formatting:** The data needs to be cleaned (removing errors, missing values), transformed, and formatted in a way the machine can understand.
# *   **Feature Engineering:** This is the process of selecting and transforming raw data into "features" that are relevant for the AI model to learn from. For example, if predicting house prices, features might include square footage, number of bedrooms, location, etc.
#
# **2. Choosing a Model/Algorithm:**
# *   **The Recipe:** An "algorithm" is like a recipe that defines how the machine will learn. There are many types, each suited for different problems. Examples include:
#     *   **Linear Regression:** Predicting a continuous value (e.g., house prices).
#     *   **Decision Trees:** Making decisions based on a series of if/then rules.
#     *   **Support Vector Machines (SVMs):** Classifying data by finding the best boundary between categories.
#     *   **Neural Networks:** (More on this below) Complex models inspired by the human brain.
#
# **3. Training the Model:**
# *   **Learning Phase:** The prepared data is fed into the chosen algorithm. The algorithm adjusts its internal parameters (called "weights" and "biases") as it tries to find patterns and relationships within the data.
# *   **Optimization:** The goal is to minimize the "error" or "loss" – how far off the model's predictions are from the actual values in the training data. It does this iteratively, often using a technique called "gradient descent" which is like slowly descending a hill to find the lowest point.
#
# **4. Evaluation:**
# *   **Testing:** Once trained, the model is tested on a separate set of data it has *never seen before*. This is crucial to ensure it has learned general patterns and not just memorized the training data (a problem called "overfitting").
# *   **Metrics:** Performance is measured using various metrics (e.g., accuracy, precision, recall, F1-score) depending on the problem.
#
# **5. Deployment & Prediction:**
# *   If the model performs well, it's deployed into a real-world system. When new, unseen data comes in, the model uses its learned patterns to make predictions or decisions.
#
# ---
#
# ### Types of Machine Learning
#
# 1.  **Supervised Learning:**
#     *   **How it works:** The model learns from "labeled" data, meaning each piece of input data has a corresponding correct output.
#     *   **Analogy:** Learning with a teacher who provides correct answers.
#     *   **Examples:**
#         *   **Classification:** Predicting a category (e.g., "spam" or "not spam" email, "cat" or "dog" in an image).
#         *   **Regression:** Predicting a continuous value (e.g., house price, temperature).
#
# 2.  **Unsupervised Learning:**
#     *   **How it works:** The model learns from "unlabeled" data, trying to find hidden patterns, structures, or relationships on its own.
#     *   **Analogy:** Learning by observation, without a teacher.
#     *   **Examples:**
#         *   **Clustering:** Grouping similar data points together (e.g., customer segmentation).
#         *   **Dimensionality Reduction:** Simplifying complex data while retaining important information.
#
# 3.  **Reinforcement Learning:**
#     *   **How it works:** The model (an "agent") learns by interacting with an environment. It performs actions and receives "rewards" for good actions and "penalties" for bad ones, gradually learning the optimal strategy to maximize its cumulative reward.
#     *   **Analogy:** Learning through trial and error, like a child learning to ride a bike.
#     *   **Examples:** Game playing (AlphaGo, chess engines), robotics, self-driving cars (in simulations).
#
# ---
#
# ### Deep Learning (DL): The Powerhouse
#
# Deep Learning is a specialized subset of Machine Learning that uses **Artificial Neural Networks** with multiple layers (hence "deep"). These networks are loosely inspired by the structure and function of the human brain.
#
# **1. Artificial Neural Networks (ANNs):**
# *   **Neurons (Nodes):** Basic processing units, like brain cells. Each neuron receives inputs, performs a simple computation, and passes the output to other neurons.
# *   **Layers:** Neurons are organized into layers:
#     *   **Input Layer:** Receives the raw data.
#     *   **Hidden Layers:** One or more layers between input and output where the complex computations and pattern recognition happen. The more hidden layers, the "deeper" the network.
#     *   **Output Layer:** Produces the final prediction or decision.
# *   **Weights and Biases:** Connections between neurons have "weights" (determining the strength of the connection) and "biases" (additional values). These are the parameters that the network adjusts during training.
# *   **Activation Functions:** These determine whether a neuron "fires" (activates) and passes information to the next layer, adding non-linearity to the model.
#
# **2. How Deep Learning Networks Learn:**
# *   **Forward Propagation:** Input data travels through the network, layer by layer, with each neuron performing its computation until an output is produced.
# *   **Loss Calculation:** This output is compared to the actual target (in supervised learning), and the "loss" (error) is calculated.
# *   **Backpropagation:** This is the magic! The calculated error is propagated backward through the network. This process determines how much each weight and bias in the network contributed to the error.
# *   **Gradient Descent (Optimization):** Based on the backpropagated error, the weights and biases are adjusted slightly to reduce the error for the next iteration. This iterative process continues over many "epochs" (passes through the entire dataset) until the network's predictions are as accurate as possible.
#
# **3. Types of Deep Learning Architectures:**
# *   **Convolutional Neural Networks (CNNs):** Excellent for image and video analysis (e.g., recognizing objects, facial recognition). They automatically learn hierarchical features from spatial data.
# *   **Recurrent Neural Networks (RNNs) / LSTMs / Transformers:** Designed for sequential data like text, speech, and time series (e.g., language translation, chatbots, speech recognition). Transformers, in particular, power large language models like ChatGPT.
#
# ---
#
# ### Key Enablers of Modern AI
#
# *   **Massive Data:** The availability of huge datasets from the internet, sensors, etc.
# *   **Computational Power:** Powerful GPUs (Graphics Processing Units) and specialized hardware (TPUs) make training complex deep learning models feasible.
# *   **Advanced Algorithms:** Continuous research and development of more efficient and effective learning algorithms.
#
# ---
#
# ### In Summary
#
# AI, particularly through Machine Learning and Deep Learning, works by providing algorithms with vast amounts of data. These algorithms then learn to identify patterns, make predictions, and complete tasks without being explicitly programmed for every scenario. It's a process of iterative learning, adjustment, and optimization, enabling machines to perform increasingly complex and intelligent behaviors.

# %% [markdown]
# Let's head over to the weave URL to check out the generated response.
