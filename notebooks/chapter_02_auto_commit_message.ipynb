# %% [markdown]
# # Chapter 2: Programmatic and LLM Evaluations
#
# This code notebook is part of Chapter 2 lesson of the [LLM Apps: Evaluation course](https://wandb.ai/site/courses/evals/).
#
# # How basic evals can improve your LLM system?
#
# <a target="_blank" href="https://colab.research.google.com/github/wandb/eval-course/blob/main/notebooks/chapter_02_auto_commit_message.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <!--- @wandbcode{eval-course-02} -->
#
# Programmatic evaluation is easy to setup and can help improve your LLM system. It's a low hanging fruit and thus best to start from here.
#
# Code-based grading, often referred to as “unit testing,” “heuristic-based evaluation,” “rule-based evaluation,” “programmatic evaluation,” or "assertion based evaluation," relies on predefined code—typically using string matching, regular expressions, or other heuristics—to assess model outputs. This approach is ideal in scenarios where exact matches or specific key phrases define correctness, as it’s both fast and reliable.
#
# ### Steps:
#
# - **Define Unit Objectives**: Break down what you want to evaluate into specific, testable objectives. IMPORTANT: these objectives can be expressed using a programming language.
#
# - **Implement Code Checks**: Write code that verifies whether the model’s output meets each objective.
#
# - **Iterate and Refine**: Continuously improve your evaluation criteria and code based on the model’s performance and edge cases.
#
# ### Tips:
#
# - **Start Here**: Code-based evaluation is a great starting point for evaluating your LLM application. It’s straightforward, modular, and allows for quick feedback.
#
# - **Refine Your Criteria**: This process often reveals limitations in your evaluation criteria, helping you think critically about what constitutes a “good” response.
#
# - **Keep It Simple**: Focus on keeping evaluations simple and modular, which will make them easier to maintain.
#
# - **Integrate with CI/CD**: These unit tests can seamlessly fit into your CI/CD pipeline or act as guardrails, ensuring your application’s outputs meet basic standards before deployment.

# %% [markdown]
# ## Setup
#
# Run the code cells below to setup your colab notebook.

# %%
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # !git clone --branch main https://github.com/wandb/eval-course
    # %cd eval-course
    # %cd notebooks
else:
    print("Not running in Google Colab. Skipping git clone.")

# !pip install -qq google-generativeai weave
# Out:
# Cloning into 'eval-course'...
# remote: Enumerating objects: 271, done.
# remote: Counting objects: 100% (144/144), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 271 (delta 115), reused 96 (delta 86), pack-reused 127 (from 1)
# Receiving objects: 100% (271/271), 1.19 MiB | 18.71 MiB/s, done.
# Resolving deltas: 100% (167/167), done.
# /content/eval-course/notebooks/eval-course/notebooks/eval-course
# /content/eval-course/notebooks/eval-course/notebooks/eval-course/notebooks

# %%
import os
import re
import getpass
import weave
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# utility script
from utils.llm_client import LLMClient

import nest_asyncio
nest_asyncio.apply()

# %%
import google.generativeai as genai

os.environ["GOOGLE_API_KEY"] = getpass.getpass("Please enter your GOOGLE API KEY with Gemini acccess: ")
# Out:
# Please enter your GOOGLE API KEY with Gemini acccess: ··········

# %%
# initialize weave for tracing and evaluation
weave_client = weave.init(project_name="eval-course")

# %% [markdown]
# ## Generate Commit Messages from Code Diffs
#
# Imagine you’re working on a project with multiple engineers actively contributing to the same codebase. In a high-velocity environment like this, it’s crucial to maintain clear, informative commit messages to document code changes. Proper commit messages help track code evolution, make debugging easier, and support knowledge transfer across team members.
#
# In this example, **we’ll explore using LLMs to automatically generate commit messages based on code diffs**. Automating this process can save time and maintain consistency, but *it’s essential that the generated commit messages meet certain standards*.
#
# We’ll start by generating commit messages for a sample code diff. Then, we’ll demonstrate how to use code-based evaluation to assess whether these messages meet our standards, using simple checks to ensure quality and relevance.

# %% [markdown]
# ### Part 1: Commit Generator Application

# %%
MODEL = "gemini-2.5-flash"
MODEL_CLIENT = "gemini"

# %%
class CommitMessageGenerator(weave.Model):
    model: LLMClient = LLMClient(model_name=MODEL, client_type=MODEL_CLIENT)
    prompt_template: str = """Generate a clear and descriptive commit message for the following code changes.
    Format the commit message in the conventional commits style:
    <type>(<scope>): <description>

    [optional body]

    Code diff:
    {code_diff}

    Focus on:
    - What changed?
    - Why it changed?
    - Any breaking changes
    """

    @weave.op()
    def predict(self, diff: str) -> str:
        prompt = self.prompt_template.format(code_diff=diff)
        response = self.model.predict(user_prompt=prompt)
        return response.strip()

# %%
diff_example_1 = """
diff --git a/src/auth.py b/src/auth.py
index abc123..def456 100644
--- a/src/auth.py
+++ b/src/auth.py
@@ -10,6 +10,12 @@ class AuthManager:
     def validate_token(self, token):
         return self.jwt.decode(token, self.secret_key)

+    def refresh_token(self, old_token):
+        if not self.validate_token(old_token):
+            raise InvalidTokenError
+        user_data = self.jwt.decode(old_token)
+        return self.generate_token(user_data)
"""

commit_msg_generator = CommitMessageGenerator()
commit_msg_1 = commit_msg_generator.predict(diff_example_1)
print(commit_msg_1)
# Out:
# weave: 🍩 https://wandb.ai/chrismorgan/eval-course/r/call/019d4ae1-753b-7503-a4e1-9f26b90da3ee
# ```
# feat(auth): Add JWT token refresh functionality
#
# Implement `AuthManager.refresh_token` method to allow clients to obtain a new
# JWT using an existing valid token.
#
# This method enables the application to issue new access tokens without requiring
# users to re-authenticate, improving user experience while enhancing security by
# facilitating shorter-lived access tokens.
#
# The refresh process involves:
# - Validating the `old_token`.
# - Decoding user data from the valid `old_token`.
# - Generating and returning a brand new token using the extracted user data.
# - Raising an `InvalidTokenError` if the provided `old_token` is invalid.
# ```

# %% [markdown]
# ### Part 2: Code based evaluation
#
# In this section, we will define a few objective criterias and write a programmatic (no use of LLMs) functions to evaluate the quality of the commit messages.
#
# A good commit message on a high-level should:
#
# - Summarize the changes accurately and concisely.
#
# - Highlight key functions, methods, or modules affected.
#
# - Be free of unnecessary information or “fluff.”
#
# Below we are converting these high-level concepts into unit objectives.
#
# Are these objectives "actually" capturing the full extent of the "quality" measure of the generated commit messages? In this case, it is not.
#
# But the main selling point is "the speed of writing few criterias/objectives as function and the speed of running them".

# %%
# Define objectives as functions

# @weave.op()
def follows_conventional_format(model_output: str) -> bool:
    """Check if commit message follows conventional commit format"""
    conv_commit_pattern = r'^(feat|fix|perf|refactor|style|test|docs|build|ci|chore)(\([a-z-]+\))?: .+'
    return bool(re.match(conv_commit_pattern, model_output.split('\n')[0]))


# @weave.op()
def length_appropriate(model_output: str) -> bool:
    """Check if commit message length is appropriate (between 10-72 chars)"""
    first_line = model_output.split('\n')[0]
    return 10 <= len(first_line) <= 72


# @weave.op()
def contains_key_components(model_output: str) -> bool:
    """Check if commit message contains key components (what and why)"""
    return (
        any(word in model_output.lower() for word in ["add", "update", "fix", "remove", "implement"]) and
        ("to" in model_output.lower() or "for" in model_output.lower() or "because" in model_output.lower())
    )


# @weave.op()
def no_generic_terms(model_output: str) -> bool:
    """Check if commit message avoids generic terms"""
    generic_terms = ["stuff", "things"]
    return not any(term in model_output.lower() for term in generic_terms)


# @weave.op()
def has_imperative_mood(model_output: str) -> bool:
    """Check if commit message uses imperative mood (starts with verb)"""
    first_word = model_output.split('\n')[0].split()[0].lower()
    imperative_verbs = ["add", "update", "fix", "remove", "implement", "change", "refactor", "optimize", "delete", "create"]
    return any(first_word == verb for verb in imperative_verbs)


# @weave.op()
def has_proper_capitalization(model_output: str) -> bool:
    """Check if commit message follows proper capitalization (first letter capitalized, no period)"""
    first_line = model_output.split('\n')[0]
    return (first_line[0].isupper() and
            not first_line.endswith('.'))


# @weave.op()
def has_scope_if_needed(model_output: str) -> bool:
    """Check if commit message includes scope when appropriate"""
    first_line = model_output.split('\n')[0]
    type_with_scope = r'^(feat|fix|refactor)(\([a-z-]+\)): '
    type_without_scope = r'^(docs|test|style|chore): '
    return bool(re.match(type_with_scope, first_line) or re.match(type_without_scope, first_line))


# @weave.op()
def has_detailed_body_if_complex(model_output: str) -> bool:
    """Check if commit message has detailed body for complex changes"""
    lines = model_output.split('\n')
    # Complex changes indicated by certain keywords
    complex_indicators = ["refactor", "breaking", "deprecate", "remove", "!:"]
    is_complex = any(indicator in lines[0].lower() for indicator in complex_indicators)

    if is_complex:
        # Should have at least one line of body text after blank line
        return len(lines) >= 3 and lines[1].strip() == "" and any(line.strip() for line in lines[2:])
    return True


def _compute_criteria_wise_scores(output: str):
    # Ensure output is a string before processing
    if not isinstance(output, str):
        return {
            "follows_conventional_format": False,
            "length_appropriate": False,
            "contains_key_components": False,
            "no_generic_terms": False,
            "has_imperative_mood": False,
            "has_proper_capitalization": False,
            "has_scope_if_needed": False,
            "has_detailed_body_if_complex": False,
        }

    scores = {
        "follows_conventional_format": follows_conventional_format(output),
        "length_appropriate": length_appropriate(output),
        "contains_key_components": contains_key_components(output),
        "no_generic_terms": no_generic_terms(output),
        "has_imperative_mood": has_imperative_mood(output),
        "has_proper_capitalization": has_proper_capitalization(output),
        "has_scope_if_needed": has_scope_if_needed(output),
        "has_detailed_body_if_complex": has_detailed_body_if_complex(output),
    }
    return scores

# %% [markdown]
# I have synthetically generated a dataset of code diffs. Let's load it and see what it looks like.
#
# In pratice, you can build this  diffs from your existing code

# %%
code_diffs_dataset = weave.ref('weave:///eval-course/eval-course-dev/object/code-diffs:JJTbwBlIr6YqYARd7Yt3epxHkYLwXf7u5YxiYy2vJ7w').get()
print("Total number of samples: ", len(code_diffs_dataset.rows))

print(code_diffs_dataset.rows[0]["diff"], sep="\n")
# Out:
# Total number of samples:  10
#
# diff --git a/src/user.py b/src/user.py
# index abc123..def456 100644
# --- a/src/user.py
# +++ b/src/user.py
# @@ -10,6 +10,9 @@ class User:
#      def get_name(self):
#          return self.name
#
# +    def get_email(self):
# +        return self.email
# +

# %% [markdown]
# Note that we are not concerned about "gold" standard commit messages here. We have the user query - in the form of code diffs. We will evaluate the quality of the commit messages generated by LLMs directly using the above defined criterias. This is the beauty and one of the pros of code based evaluation.
#
# Below I am collecting all the different code based criterias under one `Scorer`. The `summarize` method will run at the end of the scoring process to aggregate the scores. If you don't write this method, `auto_summarize` will be called by default. The example below shows how to structure your code evaluation logic along with custom aggregation logic.

# %%
# Let's test if our criterias are working!
def _compute_criteria_wise_scores(output: str):
    scores = {
        "follows_conventional_format": follows_conventional_format(output),
        "length_appropriate": length_appropriate(output),
        "contains_key_components": contains_key_components(output),
        "no_generic_terms": no_generic_terms(output),
        "has_imperative_mood": has_imperative_mood(output),
        "has_proper_capitalization": has_proper_capitalization(output),
        "has_scope_if_needed": has_scope_if_needed(output),
        "has_detailed_body_if_complex": has_detailed_body_if_complex(output),
    }
    return scores

_compute_criteria_wise_scores(commit_msg_1)
# Out:
# {'follows_conventional_format': False,
#  'length_appropriate': False,
#  'contains_key_components': True,
#  'no_generic_terms': True,
#  'has_imperative_mood': False,
#  'has_proper_capitalization': False,
#  'has_scope_if_needed': False,
#  'has_detailed_body_if_complex': True}

# %%
from typing import Optional
from weave import Scorer


class CodeDiffScorer(Scorer):
    @weave.op()
    def score(self, output: str) -> dict:
        # compute scores row wise
        result = _compute_criteria_wise_scores(output)
        return result

    @weave.op()
    def summarize(self, score_rows: list) -> Optional[dict]:
        # aggregate the results
        if not score_rows:
            return None

        # Initialize counters for each metric with weight 1
        metrics = {
            'follows_conventional_format': {'weight': 1, 'count': 0},
            'length_appropriate': {'weight': 1, 'count': 0},
            'contains_key_components': {'weight': 1, 'count': 0},
            'no_generic_terms': {'weight': 1, 'count': 0},
            'has_imperative_mood': {'weight': 1, 'count': 0},
            'has_proper_capitalization': {'weight': 1, 'count': 0},
            'has_scope_if_needed': {'weight': 1, 'count': 0},
            'has_detailed_body_if_complex': {'weight': 1, 'count': 0}
        }

        # Sum up scores for each metric
        total = len(score_rows)
        for row in score_rows:
            for metric in metrics:
                # Safely get the metric value, defaulting to False if missing
                if row.get(metric, False):
                    metrics[metric]['count'] += 1

        # Calculate criteria wise score
        criteria_wise_score = {}
        for metric_name in metrics:
            criteria_wise_score[metric_name] = metrics[metric_name]['count'] / total

        # Calculate weighted average score
        weighted_sum = sum(
            (metrics[metric]['count'] / total) * metrics[metric]['weight']
            for metric in metrics
        )
        total_weights = sum(metrics[metric]['weight'] for metric in metrics)
        code_eval_score = weighted_sum / total_weights

        summary = {'code_eval_score': code_eval_score}
        summary.update(criteria_wise_score)

        print(summary)

        return summary

code_evaluator = CodeDiffScorer()

# %% [markdown]
# Let's run the evaluation.

# %%
import asyncio
from weave import Evaluation, Dataset

# Create evaluation
evaluation = Evaluation(
    dataset=Dataset(rows=code_diffs_dataset.rows),
    scorers=[code_evaluator]
)

# Run evaluation
asyncio.run(evaluation.evaluate(CommitMessageGenerator()))
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 183.08ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/960412499.py", line 21, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 11.340644664s.
# weave:
# weave: Evaluated 1 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 312.13ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/960412499.py", line 21, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 11.221860879s.
# weave:
# weave: Evaluated 2 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 469.82ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/960412499.py", line 21, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 11.077322651s.
# weave:
# weave: Evaluated 3 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 652.25ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/960412499.py", line 21, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 10.86231177s.
# weave:
# weave: Evaluated 4 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 867.08ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/960412499.py", line 21, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 10.655782582s.
# weave:
# weave: Evaluated 5 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 164.56ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/960412499.py", line 21, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 10.492130156s.
# weave:
# weave: Evaluated 6 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 344.88ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/960412499.py", line 21, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 10.31819496s.
# weave:
# weave: Evaluated 7 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 499.08ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/960412499.py", line 21, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 10.158001326s.
# weave:
# weave: Evaluated 8 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 677.10ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/960412499.py", line 21, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 9.966485491s.
# weave:
# weave: Evaluated 9 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 909.34ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/960412499.py", line 21, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 9.737193733s.
# weave:
# weave: Evaluated 10 of 10 examples
# weave: Evaluation summary {
# weave:   "CodeDiffScorer": {
# weave:     "code_eval_score": 0.0,
# weave:     "follows_conventional_format": 0.0,
# weave:     "length_appropriate": 0.0,
# weave:     "contains_key_components": 0.0,
# weave:     "no_generic_terms": 0.0,
# weave:     "has_imperative_mood": 0.0,
# weave:     "has_proper_capitalization": 0.0,
# weave:     "has_scope_if_needed": 0.0,
# weave:     "has_detailed_body_if_complex": 0.0
# weave:   },
# weave:   "model_latency": {
# weave:     "mean": 1.0214045763015747
# weave:   }
# weave: }
# {'code_eval_score': 0.0, 'follows_conventional_format': 0.0, 'length_appropriate': 0.0, 'contains_key_components': 0.0, 'no_generic_terms': 0.0, 'has_imperative_mood': 0.0, 'has_proper_capitalization': 0.0, 'has_scope_if_needed': 0.0, 'has_detailed_body_if_complex': 0.0}
# {'CodeDiffScorer': {'code_eval_score': 0.0,
#   'follows_conventional_format': 0.0,
#   'length_appropriate': 0.0,
#   'contains_key_components': 0.0,
#   'no_generic_terms': 0.0,
#   'has_imperative_mood': 0.0,
#   'has_proper_capitalization': 0.0,
#   'has_scope_if_needed': 0.0,
#   'has_detailed_body_if_complex': 0.0},
#  'model_latency': {'mean': 1.0214045763015747}}

# %% [markdown]
# ### Part 3: Improve the application with learnings
#
# Doing the exercise of writing code based evaluation criterias can in turn help improve the application. Below, I have added instructions in the `prompt_template` that in theory should help improve the `code_eval_score` metric.

# %%
class CommitMessageGenerator(weave.Model):
    model: LLMClient = LLMClient(model_name=MODEL, client_type=MODEL_CLIENT)
    prompt_template: str = """Generate a clear and descriptive commit message for the following code changes.
    Format the commit message in the conventional commits style:
    <type>(<scope>): <description>

    [optional body]

    Code diff:
    {code_diff}

    Focus on:
    - What changed?
    - Why it changed?
    - Any breaking changes

    Make sure to follow these instructions:

    - Format Compliance: Begin with a type (e.g., feat, fix), optional scope, and a colon.
    - Length: Keep the main message between 10-72 characters.
    - Key Components: Include what changed and why (e.g., “add… to improve…”).
    - Avoid Generic Terms: Avoid vague words like “stuff,” “updated,” or “changed.”
    - Imperative Mood: Start with an action verb in imperative form (e.g., “add,” “fix”).
    - Capitalization: Capitalize the first word; avoid ending with a period.
    - Scope Usage: Use a scope if relevant (e.g., feat(auth): ...).
    - Detailed Body: For complex changes, include a detailed body after a blank line.
    """

    @weave.op()
    def predict(self, diff: str) -> str:
        prompt = self.prompt_template.format(code_diff=diff)
        response = self.model.predict(user_prompt=prompt)
        return response.strip()

# %%
asyncio.run(evaluation.evaluate(CommitMessageGenerator()))
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 383.54ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/761549592.py", line 32, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 9.253687435s.
# weave:
# weave: Evaluated 1 of 10 examples
# weave: 🍩 https://wandb.ai/chrismorgan/eval-course/r/call/019d4ae1-8b40-7ffb-b3ee-1eb973bf9de6
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 639.23ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/761549592.py", line 32, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 9.005007278s.
# weave:
# weave: Evaluated 2 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 770.97ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/761549592.py", line 32, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 8.851017245s.
# weave:
# weave: Evaluated 3 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 901.81ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/761549592.py", line 32, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 8.725632841s.
# weave:
# weave: Evaluated 4 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 157.41ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/761549592.py", line 32, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 8.562982745s.
# weave:
# weave: Evaluated 5 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 312.58ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/761549592.py", line 32, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 8.412412726s.
# weave:
# weave: Evaluated 6 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 504.15ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/761549592.py", line 32, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 8.24009857s.
# weave:
# weave: Evaluated 7 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 695.79ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/761549592.py", line 32, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 8.042502771s.
# weave:
# weave: Evaluated 8 of 10 examples
# weave: 🍩 https://wandb.ai/chrismorgan/eval-course/r/call/019d4ae1-92b1-7d04-8db9-a13213010f47
# weave: Evaluated 9 of 10 examples
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 185.51ms
# weave: model_output failed
# weave: Traceback (most recent call last):
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/flow/model.py", line 143, in apply_model_async
# weave:     model_output, model_call = await async_call_op(
# weave:                                ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# weave:     return await loop.run_in_executor(None, func_call)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# weave:     yield self  # This tells Task to wait for completion.
# weave:     ^^^^^^^^^^
# weave:   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# weave:     future.result()
# weave:   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# weave:     raise self._exception.with_traceback(self._exception_tb)
# weave:   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# weave:     result = self.fn(*self.args, **self.kwargs)
# weave:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op_caller.py", line 53, in <lambda>
# weave:     lambda: func.call(*args, __should_raise=True, **kwargs)
# weave:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1187, in call
# weave:     return _call_sync_func(
# weave:            ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/tmp/ipykernel_15908/761549592.py", line 32, in predict
# weave:     response = self.model.predict(user_prompt=prompt)
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 188, in predict
# weave:     return self.execute_gemini_sdk(user_prompt, system_prompt, schema)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 1296, in wrapper
# weave:     res, _ = _call_sync_func(
# weave:              ^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/weave/trace/op.py", line 546, in _call_sync_func
# weave:     res = func(*args, **kwargs)
# weave:           ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/content/eval-course/notebooks/utils/llm_client.py", line 99, in execute_gemini_sdk
# weave:     response = model.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
# weave:     response = self._client.generate_content(
# weave:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
# weave:     response = rpc(
# weave:                ^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py", line 128, in __call__
# weave:     return wrapped_func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
# weave:     return retry_target(
# weave:            ^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
# weave:     next_sleep = _retry_error_helper(
# weave:                  ^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py", line 216, in _retry_error_helper
# weave:     raise final_exc from source_exc
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
# weave:     result = target()
# weave:              ^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py", line 130, in func_with_timeout
# weave:     return func(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py", line 55, in error_remapped_callable
# weave:     return callable_(*args, **kwargs)
# weave:            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# weave:   File "/usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 1161, in __call__
# weave:     raise core_exceptions.from_http_response(response)
# weave: google.api_core.exceptions.TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# weave: * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# weave: Please retry in 351.17653ms.
# weave:
# weave: Evaluated 10 of 10 examples
# weave: Evaluation summary {
# weave:   "CodeDiffScorer": {
# weave:     "code_eval_score": 0.037500000000000006,
# weave:     "follows_conventional_format": 0.0,
# weave:     "length_appropriate": 0.0,
# weave:     "contains_key_components": 0.1,
# weave:     "no_generic_terms": 0.1,
# weave:     "has_imperative_mood": 0.0,
# weave:     "has_proper_capitalization": 0.0,
# weave:     "has_scope_if_needed": 0.0,
# weave:     "has_detailed_body_if_complex": 0.1
# weave:   },
# weave:   "model_latency": {
# weave:     "mean": 2.712885308265686
# weave:   }
# weave: }
# {'code_eval_score': 0.037500000000000006, 'follows_conventional_format': 0.0, 'length_appropriate': 0.0, 'contains_key_components': 0.1, 'no_generic_terms': 0.1, 'has_imperative_mood': 0.0, 'has_proper_capitalization': 0.0, 'has_scope_if_needed': 0.0, 'has_detailed_body_if_complex': 0.1}
# {'CodeDiffScorer': {'code_eval_score': 0.037500000000000006,
#   'follows_conventional_format': 0.0,
#   'length_appropriate': 0.0,
#   'contains_key_components': 0.1,
#   'no_generic_terms': 0.1,
#   'has_imperative_mood': 0.0,
#   'has_proper_capitalization': 0.0,
#   'has_scope_if_needed': 0.0,
#   'has_detailed_body_if_complex': 0.1},
#  'model_latency': {'mean': 2.712885308265686}}

# %% [markdown]
# In practice, this is an iterative cycyle. This colab notebook is showing just the first iteration but I hope you get the point. :)
